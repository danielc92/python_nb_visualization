# %% [markdown]
# # Seaborn factorplot
# - https://seaborn.pydata.org/generated/seaborn.factorplot.html#seaborn.factorplot
# - "Draw a categorical plot onto a FacetGrid."

# %% [markdown]
# ## Import modules

# %%
import seaborn
import pandas

# %% [markdown]
# ## Load data

# %%
tips = pandas.read_csv("/users/danielcorcoran/Desktop/github_repos/python_nb_visualization/seaborn_official_datasets/tips.csv")
titanic = pandas.read_csv("/users/danielcorcoran/Desktop/github_repos/python_nb_visualization/seaborn_official_datasets/titanic.csv")
carcrashes = pandas.read_csv("/users/danielcorcoran//desktop/github_repos/python_nb_visualization/seaborn_official_datasets/car_crashes.csv")
exercise = pandas.read_csv("/users/danielcorcoran/Desktop/github_repos/python_nb_visualization/seaborn_official_datasets/exercise.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["sex"].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Factorplot bar using tips dataset

# %%
seaborn.factorplot(data = tips,
                  x = "day",
                  y = "total_bill",
                  kind = "bar",
                  col = "sex",
                  legend = True)

# %% [markdown]
# ### Factorplot point using exercise dataset

# %%
seaborn.factorplot(data = exercise, 
                  x = "time",
                  y = "pulse",
                  #hue = "kind", 
                  col = "diet",
                  legend = True,
                  estimator = sum)

# %% [markdown]
# ### Factorplot point using exercise dataset, splitting data by 'kind'

# %%
seaborn.factorplot(data = exercise, 
                  x = "time",
                  y = "pulse",
                  hue = "kind", 
                  col = "diet",
                  legend = True)

# %%
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# ### Factorplot bar using titanic dataset
# - 'bar' kind will average by default

# %%
seaborn.factorplot(data = titanic,
                  x = "sex",
                  y = "survived",
                  kind = "bar",
                  #estimator = sum,
                  legend = True)

# %% [markdown]
# ### Adding estimator parameter (sum) to Factorplot above gives the sum of 'survived'

# %%
seaborn.factorplot(data = titanic,
                  x = "sex",
                  y = "survived",
                  kind = "bar",
                  estimator = sum,
                  legend = True)

# %% [markdown]
# ### Factorplot count of titanic dataset splitting by surived

# %%
seaborn.factorplot(data = titanic,
                  x = "sex",
                  col = "survived",
                  kind = "count",
                  estimator = sum,
                  legend = True)

# %% [markdown]
# ### Factorplot count of titanic dataset splitting by surived

# %%
seaborn.factorplot(data = titanic,
                  x = "class",
                  y = "survived",
                  kind = "bar",
                  estimator = sum,
                  col = "sex",
                  size = 6)

# %% [markdown]
# ### Factorplot bar of tips dataset, splitting by 'time', with custom palette

# %%
seaborn.factorplot(data = tips,
                  x = "sex",
                   y = "total_bill",
                   kind = "bar",
                  col = "time",
                  palette = ["orange", "purple"])

# %% [markdown]
# ### Factorplot swarm of tips dataset, splitting by 'day'

# %%
seaborn.factorplot(data = tips,
                  x = "sex",
                  y = "tip",
                  kind = "swarm",
                   hue = "smoker",
                  col = "day",
                  col_wrap = 2,
                  size = 6)

# %% [markdown]
# ### Appending column to tips dataset to bin tips

# %%
tips["tip_bracket"] = pandas.cut(x = tips["tip"],bins=5)

# %% [markdown]
# ### Factorplot strip (scatter) using tips dataset, splitting by 'day'

# %%
seaborn.factorplot(data = tips,
                 x = 'tip_bracket',
                 y = 'total_bill',
                 hue = "sex",
                 kind = "strip",
                 col = "day", 
                 col_wrap = 2,
                  size = 6)

# %%
carcrashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
import numpy

# %%
for index in range(carcrashes.shape[0]):
        r = numpy.random.randint(1,5)
        carcrashes.loc[index, "category"] = r

# %%
carcrashes.head(2)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
#
#    ins_losses abbrev  category
# 0      145.08     AL       4.0
# 1      133.93     AK       3.0

# %% [markdown]
# ### Factorplot strip plot split by category with size scaling 7

# %%
seaborn.factorplot(data = carcrashes,
                  kind = "strip",
                  x = "alcohol",
                  y = "speeding",
                  col = "category",
                  col_wrap = 2,
                  size = 7,
                  aspect = 1.23)

# %% [markdown]
# ### Factorplot bar using titanic dataset, with custom col order and bar split by sex

# %%
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
seaborn.factorplot(data = titanic,
                  x = "who",
                  y = "survived",
                   col = "class",
                   col_order =  ["First", "Second", "Third"],
                  kind = "bar",
                   hue = "sex",
                   palette = [],
                  estimator = sum)\
.savefig("titanic_bar_who.svg")

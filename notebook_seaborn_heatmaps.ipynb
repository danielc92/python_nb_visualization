# %% [markdown]
# # Seaborn heatmaps

# %% [markdown]
# ## Import modules

# %%
import pandas
import seaborn
import numpy

# %% [markdown]
# ## Export Path

# %%
export_path = "/users/danielcorcoran/desktop/github_repos/python_nb_visualization/seaborn_exports/"

# %% [markdown]
# ## Show available colour palettes

# %%
from IPython.display import Image, display

# %%
display(Image(filename = "/users/danielcorcoran//desktop/github_repos/python_nb_visualization/palettes.png"))

# %% [markdown]
# ## Set figure size global

# %%
seaborn.set(rc={'figure.figsize':(12,9)})
seaborn.set_style('whitegrid')

# %% [markdown]
# ## Create random data for testing heatmaps

# %%
random_data = pandas.DataFrame(numpy.random.rand(12,12))

# %%
random_data
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.308466  0.110409  0.882932  0.930573  0.587653  0.590136  0.230617
# 1   0.094499  0.518820  0.768650  0.701867  0.275220  0.431465  0.484878
# 2   0.861698  0.048778  0.363685  0.890523  0.173961  0.033196  0.498078
# 3   0.511639  0.414856  0.204173  0.570524  0.739647  0.912460  0.848852
# 4   0.752144  0.883596  0.212318  0.439747  0.084700  0.969589  0.164283
# 5   0.207206  0.905175  0.213240  0.784226  0.673876  0.108031  0.667370
# 6   0.087441  0.088890  0.727627  0.763370  0.677093  0.479857  0.581510
# 7   0.385781  0.861319  0.809820  0.120283  0.548540  0.906135  0.804497
# 8   0.650505  0.000110  0.373821  0.767289  0.455117  0.679900  0.820203
# 9   0.729853  0.407876  0.599542  0.814663  0.748722  0.758642  0.191486
# 10  0.733563  0.966165  0.294818  0.716712  0.995603  0.226104  0.152955
# 11  0.805705  0.233701  0.337165  0.062291  0.954074  0.710367  0.613453
#
#           7         8         9         10        11
# 0   0.080169  0.303547  0.595026  0.872861  0.158720
# 1   0.033142  0.160126  0.021707  0.257184  0.961754
# 2   0.328452  0.217699  0.531950  0.548261  0.291018
# 3   0.946595  0.389244  0.375176  0.569213  0.064087
# 4   0.388375  0.102880  0.658922  0.372370  0.064452
# 5   0.054048  0.495143  0.116818  0.296447  0.356441
# 6   0.003426  0.109628  0.750931  0.209173  0.317371
# 7   0.409086  0.411059  0.651750  0.063878  0.843781
# 8   0.787192  0.317176  0.787494  0.161102  0.741252
# 9   0.084214  0.433460  0.684245  0.455212  0.549365
# 10  0.811678  0.121059  0.837835  0.588127  0.727469
# 11  0.716724  0.763801  0.243596  0.723390  0.320801

# %% [markdown]
# ## Create rounded down version of test data

# %%
random_data_rounded = random_data.round(1)

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Heatmap basic with custom cmap

# %%
seaborn.heatmap(data = random_data, 
                cmap = "summer").get_figure().savefig(export_path + "heatmap1.svg")

# %% [markdown]
# ### Heatmap with legend disabled

# %%
seaborn.heatmap(data = random_data, 
                cmap = "summer",
               cbar = False).get_figure().savefig(export_path + "heatmap2.svg")

# %% [markdown]
# ### Heatmap with legend truncation

# %%
seaborn.heatmap(data = random_data, 
                cmap = "bwr",
               vmin = .4,
               vmax = .8).get_figure().savefig(export_path + "heatmap3.svg")

# %% [markdown]
# ### Heatmap with value labels, using rounded test data

# %%
seaborn.heatmap(data = random_data_rounded, 
                cmap = "PuRd",
               annot = True).get_figure().savefig(export_path + "heatmap4.svg")

# %% [markdown]
# ### Heatmap with linewidth of 0.8

# %%
seaborn.heatmap(data = random_data_rounded, 
                cmap = "Accent_r",
               linewidth = 0.8).get_figure().savefig(export_path + "heatmap5.svg")

# %% [markdown]
# ### Heatmap using correlation coefficients from test data, including save to disk
# - Note: export as .svg for great scalability

# %%
corr = random_data.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

seaborn.heatmap(corr, 
                cmap = "jet_r",
                mask=mask, 
                square=True).get_figure().savefig(export_path + "heatmap6.svg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f18b232714a7> in <module>()
#       1 corr = random_data.corr()
# ----> 2 mask = np.zeros_like(corr)
#       3 mask[np.triu_indices_from(mask)] = True
#       4
#       5 seaborn.heatmap(corr,
#
# NameError: name 'np' is not defined

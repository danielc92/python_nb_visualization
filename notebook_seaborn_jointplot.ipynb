# %% [markdown]
# # Seaborn Jointplots

# %% [markdown]
# ## Import Modules

# %%
import seaborn
import matplotlib.pyplot as plt
import pandas

# %% [markdown]
# ## Set figure sizes

# %%
seaborn.set(rc={'figure.figsize':(12,8)})
seaborn.set_style('whitegrid')

# %% [markdown]
# ## Import test datasets

# %%
diamonds = pandas.read_csv("/users/danielcorcoran/desktop/github_repos/\
python_nb_visualization/seaborn_official_datasets/diamonds.csv")

tips = pandas.read_csv("/users/danielcorcoran/desktop/github_repos/\
python_nb_visualization/seaborn_official_datasets/tips.csv")

iris = pandas.read_csv("/users/danielcorcoran/desktop/github_repos/\
python_nb_visualization/seaborn_official_datasets/iris.csv")

vicnodes = pandas.read_csv("/users/danielcorcoran/desktop/github_repos/\
tableau_projects_vic_crash_stats/raw data/NODES_DPC_2.csv")

# %% [markdown]
# ## Set export paths

# %%
export_path = "/users/danielcorcoran//desktop/github_repos/python_nb_visualization/seaborn_exports/"

# %% [markdown]
# ## Preview datasets

# %%
diamonds.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Jointplot, using iris dataset, sepal_length vs sepal_width, kde type

# %%
seaborn.jointplot(data = iris, 
                  x = "sepal_length", 
                  y = "sepal_width",
                  size=10,
                  kind = "kde",
                  color = "magenta").savefig(export_path + "jointplot1.svg")

# %% [markdown]
# ### Jointplot, using iris dataset, sepal_length vs sepal_width, reg type

# %%
seaborn.jointplot(data = iris, 
                  x = "sepal_length", 
                  y = "sepal_width",
                  size=10,
                  kind = "reg",
                  color = "magenta").savefig(export_path + "jointplot2.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using iris dataset, sepal_length vs sepal_width, hex type

# %%
seaborn.jointplot(data = iris, 
                  x = "sepal_length", 
                  y = "sepal_width",
                  size=10,
                  kind = "hex",
                  color = "magenta").savefig(export_path + "jointplot3.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using diamond dataset, carat vs price, kde type

# %%
seaborn.jointplot(data = diamonds, 
                  x = "carat", 
                  y = "price",
                  size=10,
                  kind = "kde",
                  color = "red").savefig(export_path + "jointplot4.svg")

# %% [markdown]
# ### Jointplot, using diamond dataset, carat vs price, reg type

# %%
seaborn.jointplot(data = diamonds, 
                  x = "carat", 
                  y = "price",
                  size=10,
                  kind = "reg",
                  color = "red").savefig(export_path + "jointplot5.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using diamond dataset, carat vs price, resid type

# %%
seaborn.jointplot(data = diamonds, 
                  x = "carat", 
                  y = "price",
                  size=10,
                  kind = "resid",
                  color = "red").savefig(export_path + "jointplot6.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using diamond dataset, carat vs price, hex type

# %%
seaborn.jointplot(data = diamonds, 
                  x = "carat", 
                  y = "price",
                  size=10,
                  kind = "hex",
                  color = "red").savefig(export_path + "jointplot7.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
seaborn.jointplot(data = tips, 
                  x = "tip", 
                  y = "total_bill",
                  size=10,
                  kind = "kde",
                  color = "grey").savefig(export_path + "jointplot8.svg")

# %% [markdown]
# ### Jointplot, using tips dataset, tip vs total_bill, scatter type

# %%
seaborn.jointplot(data = tips, 
                  x = "tip", 
                  y = "total_bill",
                  size=10,
                  kind = "scatter",
                  color = "grey").savefig(export_path + "jointplot9.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using tips dataset, tip vs total_bill, hex type

# %%
seaborn.jointplot(data = tips, 
                  x = "tip", 
                  y = "total_bill",
                  size=10,
                  kind = "hex",
                  color = "grey").savefig(export_path + "jointplot10.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using vic crash nodes dataset, Longitude vs Latitude, hex type

# %%
seaborn.jointplot(data = vicnodes, 
                  x = "LONGITUDE", 
                  y = "LATITUDE",
                  size=10,
                  kind = "hex",
                  color = "blue").savefig(export_path + "jointplot11.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using vic crash nodes dataset, Longitude vs Latitude, scatter type

# %%
seaborn.jointplot(data = vicnodes, 
                  x = "LONGITUDE", 
                  y = "LATITUDE",
                  size=10,
                  kind = "scatter",
                  color = "blue").savefig(export_path + "jointplot12.svg")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Jointplot, using vic crash nodes dataset, Longitude vs Latitude, kde type

# %%
seaborn.jointplot(data = vicnodes, 
                  x = "LONGITUDE", 
                  y = "LATITUDE",
                  size=10,
                  kind = "kde",
                  color = "blue").savefig(export_path + "jointplot13.svg")
